# %%
import mujoco
import mujoco.viewer

model = mujoco.MjModel.from_xml_path("../../character.xml")
data = mujoco.MjData(model)
mujoco.viewer.launch(model, data)
# Out:
# /home/pipev/Documents/Proyectos/gray-boxing/rl-agent/.venv/lib/python3.14/site-packages/glfw/__init__.py:917: GLFWError: (65548) b'Wayland: The platform does not provide the window position'
#   warnings.warn(message, GLFWError)
# WARNING: OpenGL error 0x502 in or before mjr_makeContext

# %%
#
